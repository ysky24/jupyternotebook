# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.arange(-3,3,0.1) # generate -3 to 3 step 0.1
y = np.sin(x)
plt.plot(x,y)
plt.show()

# %%
# %time x = map(lambda x:2*x,range(100000))
# Out:
# Wall time: 27 ms

# %%
# %time x = map(lambda x:2*x,range(100000))
