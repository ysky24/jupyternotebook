# %% [markdown]
# # matplotlibの使い方
#
# ---
# numpy、pandas等のライブラリを組み合わせたグラフ描画ライブラリであるmatplotlibの使い方を学んでいく
#
# anaconda環境では必要ライブラリが含まれるため学習コストとが低く、簡単に学習が進められる。

# %%
# %matplotlib inline
#　 mtplotlib  plot graph on jupyter

import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.arange(-3,3,0.1) # generate -3 to 3 step 0.1
y = np.sin(x)
plt.plot(x,y)
plt.show()

# %%
y = np.cos(x)
plt.plot(x,y)
plt.show()

# %%
y1 = np.sin(x)
y2 = np.cos(x)
plt.plot(x,y1,label = "sin")
plt.plot(x,y2,linestyle="--",label = "cos")
plt.xlabel("x")
plt.ylabel("y")
plt.title('sin & cos')
plt.legend()
plt.show()

# %% [markdown]
# ## 画像の表示
#
# 愛犬を表示しています。
# 画像表示のためのメソッドimshow()を使用します。
# 画像の読み込みはimread()を使用することで行います。

# %%
from matplotlib.image import imread

img = imread('dataset/out_900.png')
plt.imshow(img)

plt.show()

# %% [markdown]
# ## 日本語フォントの使用
#
# <TODO　未完成>
# ---
# from matplotlib.font_manager import FontPropertiesにてフォントの指定が必要です。
#
# 豆腐が出ないように指定し、各引数にて追加してやれば出力されます。
#
# >windowsならWINDOWSフォルダ配下に
#
# >fp = FontProperties(fname=r'C:\WINDOWS\Fonts\YuGothic.ttf', size=14)

# %%
#case Mac
import matplotlib
import matplotlib.font_manager as font_manager
path = '/Library/Fonts/ヒラギノ丸ゴ ProN W4.ttc'
prop = font_manager.FontProperties(fname=path)
matplotlib.rcParams['font.family'] =  prop.get_name()
matplotlib.rcParams['font.size'] =  12 #ついでに文字を少し大きく
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-6-804cd1a2266c> in <module>()
#       4 path = '/Library/Fonts/ヒラギノ丸ゴ ProN W4.ttc'
#       5 prop = font_manager.FontProperties(fname=path)
# ----> 6 matplotlib.rcParams['font.family'] =  prop.get_name()
#       7 matplotlib.rcParams['font.size'] =  12 #ついでに文字を少し大きく
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\font_manager.py in get_name(self)
#     748         properties.
#     749         """
# --> 750         return get_font(findfont(self)).family_name
#     751
#     752     def get_style(self):
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Library/Fonts/ヒラギノ丸ゴ ProN W4.ttc'

# %%
# case Windows
# from matplotlib.font_manager import FontProperties

# %%
# test 
x = np.arange(-3,3,0.1) # generate -3 to 3 step 0.1
y = np.sin(x)
plt.xlabel(u"x軸")
plt.plot(x,y)
plt.show()
